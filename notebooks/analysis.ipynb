# %%
import duckdb
import pandas as pd

# %%
duckdb.sql("""
SELECT *
FROM '../data/311.csv'
LIMIT 5
""").df()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    67347473 2025-12-31 13:17:37 2026-01-06 13:59:08    HPD
# 1    67347280 2025-12-31 13:17:22 2026-01-03 11:30:46    HPD
# 2    67346288 2025-12-31 13:17:21 2025-12-31 13:56:31    HPD
# 3    67351513 2025-12-31 13:17:19 2025-12-31 14:31:39   NYPD
# 4    67351896 2025-12-31 13:17:19 2025-12-31 14:31:24    HPD
#
#                                          Agency Name  \
# 0  Department of Housing Preservation and Develop...
# 1  Department of Housing Preservation and Develop...
# 2  Department of Housing Preservation and Develop...
# 3                    New York City Police Department
# 4  Department of Housing Preservation and Develop...
#
#   Problem (formerly Complaint Type) Problem Detail (formerly Descriptor)  \
# 0                        WATER LEAK                            SLOW LEAK
# 1                    HEAT/HOT WATER                      ENTIRE BUILDING
# ...
